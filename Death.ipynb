# %% [markdown]
# Ashlee A 2/26/23

# %%
import pandas as pd

# %% [markdown]
# Importing Death info from 2015

# %%
death = pd.read_csv("C:/Users/Teacher/Downloads/archive (2).zip", index_col=0)
# Out:
# C:\Users\Teacher\AppData\Local\Temp\ipykernel_9740\880033659.py:1: DtypeWarning: Columns (40,41,42,43,61,62,63,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   death = pd.read_csv("C:/Users/Teacher/Downloads/archive (2).zip", index_col=0)

# %% [markdown]
# showing the first 10 rows, this helps me see what kind of values and data I have

# %%
death.head(10)
# Out:
#                  education_1989_revision  education_2003_revision  \
# resident_status
# 1                                    NaN                      3.0
# 1                                    NaN                      6.0
# 1                                    NaN                      3.0
# 1                                    NaN                      3.0
# 1                                    NaN                      5.0
# 1                                    NaN                      6.0
# 1                                    NaN                      4.0
# 1                                    NaN                      3.0
# 1                                    NaN                      3.0
# 1                                    NaN                      9.0
#
#                  education_reporting_flag  month_of_death sex  \
# resident_status
# 1                                       1               1   M
# 1                                       1               1   M
# ...

# %%
death.describe()
# Out:
#        education_1989_revision  education_2003_revision  \
# count             73043.000000             2.645155e+06
# mean                 12.602371             3.718700e+00
# std                   9.516661             1.985368e+00
# min                   0.000000             1.000000e+00
# 25%                  11.000000             3.000000e+00
# 50%                  12.000000             3.000000e+00
# 75%                  13.000000             5.000000e+00
# max                  99.000000             9.000000e+00
#
#        education_reporting_flag  month_of_death  detail_age_type  \
# count              2.718198e+06    2.718198e+06     2.718198e+06
# mean               9.731282e-01    6.381973e+00     1.025770e+00
# std                1.617089e-01    3.520758e+00     3.105674e-01
# min                0.000000e+00    1.000000e+00     1.000000e+00
# 25%                1.000000e+00    3.000000e+00     1.000000e+00
# 50%                1.000000e+00    6.000000e+00     1.000000e+00
# ...

# %%
death[["month_of_death", "race", "detail_age"]].describe()
# Out:
#        month_of_death          race    detail_age
# count    2.718198e+06  2.718198e+06  2.718198e+06
# mean     6.381973e+00  1.696986e+00  7.345519e+01
# std      3.520758e+00  5.282618e+00  2.230170e+01
# min      1.000000e+00  1.000000e+00  1.000000e+00
# 25%      3.000000e+00  1.000000e+00  6.300000e+01
# 50%      6.000000e+00  1.000000e+00  7.700000e+01
# 75%      9.000000e+00  1.000000e+00  8.700000e+01
# max      1.200000e+01  7.800000e+01  9.990000e+02

# %% [markdown]
# showing the deaths by age

# %%
import matplotlib 

death.hist('detail_age',range=[0, 102])
# Out:
# array([[<AxesSubplot:title={'center':'detail_age'}>]], dtype=object)

# %% [markdown]
# showing death by month

# %%
death.hist('month_of_death')
# Out:
# array([[<AxesSubplot:title={'center':'month_of_death'}>]], dtype=object)
